# %%
from pull_packages import pull_packages
pull_packages()
# Out:
# decibans
# general
# metadata

# %%
from make_decibans import make_decibans
make_decibans()
# Out:
#                  name                                               url  \
# 0                 AAM                    https://github.com/dfdx/AAM.jl
# 1        ABCDistances  https://github.com/dennisprangle/ABCDistances.jl
# 2     AbstractTensors  https://github.com/chakravala/AbstractTensors.jl
# 3       AbstractTrees          https://github.com/Keno/AbstractTrees.jl
# 4         Accelereval        https://github.com/lindahua/Accelereval.jl
# ...               ...                                               ...
# 1906           ZenFab            https://github.com/FactoryOS/ZenFab.jl
# 1907          ZipFile                 https://github.com/fhs/ZipFile.jl
# 1908             Zlib                https://github.com/dcjones/Zlib.jl
# 1909              ZMQ               https://github.com/JuliaLang/ZMQ.jl
# 1910      ZVSimulator          https://github.com/scidom/ZVSimulator.jl
#
#          category            sub_category
# 0        Graphics                Graphics
# ...

# %%
from make_general_packages import make_general_packages
make_general_packages(True)
# Out:
# CorticalSpectralTemporalResponses https://github.com/haberdashPI/CorticalSpectralTemporalResponses
# jlpkg https://github.com/fredrikekre/jlpkg
# julia https://github.com/JuliaLang/julia
# MatLang https://github.com/juliamatlab/MatLang
# UnitfulMR https://github.com/fmrilab/UnitfulMR
# VQC https://github.com/supremacyfuture/VQC
#                    name                                                url
# 0          AbaqusReader        https://github.com/JuliaFEM/AbaqusReader.jl
# 1       AbstractAlgebra      https://github.com/Nemocas/AbstractAlgebra.jl
# 2          AbstractFFTs       https://github.com/JuliaMath/AbstractFFTs.jl
# 3       AbstractIndices     https://github.com/Tokazama/AbstractIndices.jl
# 4     AbstractInstances      https://github.com/dalum/AbstractInstances.jl
# ...                 ...                                                ...
# 2720             Zomato            https://github.com/rahulkp220/Zomato.jl
# ...

# %%
from make_metadata_packages import make_metadata_packages
make_metadata_packages(True)
# Out:
# CorpusTools https://github.com/mguzmann/CorpusTools
# OnlineMoments https://git.colberg.org/peter/OnlineMoments.jl
#                         name  \
# 0            AbstractDomains
# 1              AbstractTrees
# 2                   Accumulo
# 3                       ACME
# 4     ActiveAppearanceModels
# ...                      ...
# 1138                   ZChop
# 1139                 ZipFile
# 1140                    Zlib
# 1141                     ZMQ
# 1142             ZVSimulator
#
#                                                     url
# 0           https://github.com/zenna/AbstractDomains.jl
# 1              https://github.com/Keno/AbstractTrees.jl
# 2                https://github.com/JuliaDB/Accumulo.jl
# 3                    https://github.com/HSU-ANT/ACME.jl
# 4     https://github.com/dfdx/ActiveAppearanceModels.jl
# ...                                                 ...
# 1138               https://github.com/jlapeyre/ZChop.jl
# ...

# %%
from make_starred_packages import make_starred_packages
make_starred_packages(True)
# Out:
# .................................................................................
#                  name                                                url
# 0        AbaqusReader        https://github.com/JuliaFEM/AbaqusReader.jl
# 1     AbstractAlgebra       https://github.com/wbhart/AbstractAlgebra.jl
# 2     AbstractDomains        https://github.com/zenna/AbstractDomains.jl
# 3        AbstractFFTs       https://github.com/JuliaMath/AbstractFFTs.jl
# 4     AbstractNumbers  https://github.com/SimonDanisch/AbstractNumber...
# ...               ...                                                ...
# 1573               Z3                     https://github.com/zenna/Z3.jl
# 1574             Zarr                 https://github.com/meggart/Zarr.jl
# 1575          ZipFile                  https://github.com/fhs/ZipFile.jl
# 1576              ZMQ             https://github.com/JuliaInterop/ZMQ.jl
# 1577           Zygote                https://github.com/FluxML/Zygote.jl
#
# ...
